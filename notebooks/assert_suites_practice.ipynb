# %%
def Lunch_Budget_Analyzer(price):

    if price <=10:
        return("Budget Savvy! 🤑")
    elif 10< price <=20:
        return("Reasonable choice.👍")
    elif 20< price <=35:
        return("Treat yo-self!💰")
    else:
        return("Luxury dining???💎💎")

assert Lunch_Budget_Analyzer(5) == "Budget Savvy! 🤑"
assert Lunch_Budget_Analyzer(15) == "Reasonable choice.👍"
assert Lunch_Budget_Analyzer(24) == "Treat yo-self!💰"
assert Lunch_Budget_Analyzer(50) == "Luxury dining???💎💎"

print("All tests passed successfully! 🎉")
# Out:
# All tests passed successfully! 🎉

# %%
def weather_message(temp):
    if temp >=75:
        return("Sunny Adventure!")
    elif temp >=55:
        return("Cloudy but comfy, light jacket weather!")
    elif temp >=40:
        return("Classic PNW drizzle - Layer up!")
    else:
        return("Mountain cold! Gloves required.")

assert weather_message(78) == "Sunny Adventure!"
assert weather_message(56) == "Cloudy but comfy, light jacket weather!"
assert weather_message(45) == "Classic PNW drizzle - Layer up!"
assert weather_message(35) == "Mountain cold! Gloves required."

print("All tests passed successfully!🎉")
# Out:
# All tests passed successfully!🎉

# %%
# Wizard-Elf Yarn Decision System

def wizard_yarn_activator_statement(yarn_color, skill_level):
    
     # skills decision
    if skill_level <= 3:
        skill_message = "You must knit the yarn, there is no choice, only practice."
    elif 4 <= skill_level <= 6:
        skill_message = ("Consider: do you already have another project going? "
                     "Perhaps finish one first... maybe?")
    else:
        skill_message = "You have always been the Master of your own Destiny."


    # color decision
    if yarn_color == "purple":
        color_message = "🧵✨ This yarn is PERFECT. Knit the magic garment!"
    elif yarn_color == "green":
        color_message = "🌱 Good vibes. Crochet a cozy forest piece!"
    elif yarn_color == "blue":
        color_message = "🌊 Flowy mood. Perhaps a scarf of serenity."
    else:
        color_message = "🤔 Hmm… maybe choose a different project or take a snack break!"

    
    return f"{skill_message}\n{color_message}"  

assert wizard_yarn_activator_statement("purple", 1) == 'You must knit the yarn, there is no choice, only practice.\n🧵✨ This yarn is PERFECT. Knit the magic garment!'
assert wizard_yarn_activator_statement("green",2) == 'You must knit the yarn, there is no choice, only practice.\n🌱 Good vibes. Crochet a cozy forest piece!' 
assert wizard_yarn_activator_statement("blue", 3) == 'You must knit the yarn, there is no choice, only practice.\n🌊 Flowy mood. Perhaps a scarf of serenity.'
assert wizard_yarn_activator_statement("none", 4) == 'Consider: do you already have another project going? Perhaps finish one first... maybe?\n🤔 Hmm… maybe choose a different project or take a snack break!'
assert wizard_yarn_activator_statement("purple", 5) == 'Consider: do you already have another project going? Perhaps finish one first... maybe?\n🧵✨ This yarn is PERFECT. Knit the magic garment!'
assert wizard_yarn_activator_statement("green", 6) == 'Consider: do you already have another project going? Perhaps finish one first... maybe?\n🌱 Good vibes. Crochet a cozy forest piece!'
assert wizard_yarn_activator_statement("blue", 7) == 'You have always been the Master of your own Destiny.\n🌊 Flowy mood. Perhaps a scarf of serenity.'
assert wizard_yarn_activator_statement("none", 8) == 'You have always been the Master of your own Destiny.\n🤔 Hmm… maybe choose a different project or take a snack break!'
assert wizard_yarn_activator_statement("purple", 9) == 'You have always been the Master of your own Destiny.\n🧵✨ This yarn is PERFECT. Knit the magic garment!'

print("All tests passed successfully!🎉")
# Out:
# All tests passed successfully!🎉
