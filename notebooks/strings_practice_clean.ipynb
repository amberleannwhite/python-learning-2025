# %%
first = "Data" 
last = "Engineer"
print(first + " " + last)
# Out:
# Data Engineer

# %%
print(f"{first} {last}")
# Out:
# Data Engineer

# %%
title = "data engineer"

# %%
title.upper()
# Out:
# 'DATA ENGINEER'

# %%
role = "python developer"
print(word.title())
# Out:
# Data Engineer

# %%
role = "Data Architect"
print(f"I am a {role}")
# Out:
# I am a Data Architect

# %%
language = "Python" 
years = 1 
print(f"I have been learning {language} for {years} year")
# Out:
# I have been learning Python for 1 year

# %%
language = "Python"
years = 4
print(f"I have been learning {language} for {years} year{'s' if years != 1 else ''}")
# Out:
# I have been learning Python for 4 years

# %%
skill = "Data Engineering"
level = 1 
print(f"I have {level} skill badge in {skill}")
# Out:
# I have 1 skill badge in Data Engineering

# %%
skill = "Data Engineering"
level = 1 
if level == 0:
    print(f"I am working on my skill badge in {skill}!")
elif level == 1:
    print(f"I have {level} skill badge in {skill}")
else:
    print(f"I have {level} skill badges in {skill}")
# Out:
# I have 1 skill badge in Data Engineering

# %%
def badge_statement(skill, level):
    if level == 0:
        return(f"I am working on my skill badge in {skill}!")
    elif level == 1:
        return(f"I have {level} skill badge in {skill}")
    else:
        return(f"I have {level} skill badges in {skill}")
print(badge_statement("Data Engineering", 1))
print(badge_statement("Python", 4))
# Out:
# I have 1 skill badge in Data Engineering
# I have 4 skill badges in Python

# %%
def learning_statement(language, years):
    if years ==0:
        return(f"I am just starting my journey learning {language}")
    elif years == 1:
        return(f"I have been learning {language} for {years} year")
    else:
        return(f"I have been using {language} for {years} years")
print(learning_statement("Python", 1))
print(learning_statement("Python", 0))
print(learning_statement("Python", 5))
# Out:
# I have been learning Python for 1 year
# I am just starting my journey learning Python
# I have been using Python for 5 years

# %%
def profile_summary(name, role, language, years):
    if years ==0:
        return(f"Hi, I'm {name}, and I just started my {role} role. I have just started learning {language}")
    elif years == 1:
        return(f"Hi, I'm {name}, and I just started my {role} role. I have been learning {language} for {years} year")
    else:
        return(f"Hi, I'm {name}, and I just started my {role} role. I have been learning {language} for {years} years")
print(profile_summary("Amber", "Data Engineering", "Python", 0))
# Out:
# Hi, I'm Amber, and I just started my Data Engineering role. I have just started learning Python
