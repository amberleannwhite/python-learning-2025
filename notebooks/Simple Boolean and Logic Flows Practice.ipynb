# %%
print(10>3)
# Out:
# True

# %%
age = 25
print(age>18)
# Out:
# True

# %%
score = 88
print(score !=100)
# Out:
# True

# %%
balance = 1200
if balance >1000:
    print("savings stable")
else:
    print("Time to budget carefully")
# Out:
# savings stable

# %%
balance = 1200
coach_bag = 300
if coach_bag >0.3*balance:
    print("no go bogo sale :(")
else:
    print("money in the bag, baby")
# Out:
# money in the bag, baby

# %%
hours_of_sleep = 5
coffee_cups = 2
if hours_of_sleep >= 7 or coffee_cups >= 3:
    print("High alert🚀")
else: 
    print("Surviving on sheer determination💪")
# Out:
# Surviving on sheer determination💪

# %%
def weather_message(temp):
    if temp >=75:
        return("Sunny Adventure!")
    elif temp >=55:
        return("Cloudy but comfy, light jacket weather!")
    elif temp >=40:
        return("Classic PNW drizzle - Layer up!")
    else:
        return("Mountain cold! Gloves required.")

print(weather_message(44))
# Out:
# Classic PNW drizzle - Layer up!
