# %%
try:
    age_input = input("Enter your age: ")
    age = int("twenty five") #risky part
    print("You are {age} years old.")
except ValueError:
    print("⚠️ Please enter numbers only.")
# Out:
# ⚠️ Please enter numbers only.
# Enter your age:  25

# %%
try:
    file = open("not_a_real_file.txt", "r")
    content = file.read()
except IOError:
    print("Unable to open or read the file.")
# Out:
# Unable to open or read the file.

# %%
try:
    result = 10 / 0 #will break!
except ZeroDivisionError:
    print("⚠️ Cannot divide by zero.")
finally: 
    print("Cleanup: Logging this attempt and moving on...‧₊˚🧼✩ ₊˚🫧⊹♡")
# Out:
# ⚠️ Cannot divide by zero.
# Cleanup: Logging this attempt and moving on...‧₊˚🧼✩ ₊˚🫧⊹♡
