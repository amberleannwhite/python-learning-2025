# %%
import requests
import pandas as pd

#start with an empty list
facts = []

#collect 5 cat facts in a list
for _ in range(5):
    response = requests.get("https://catfact.ninja/fact")
    data = response.json()
    facts.append(data["fact"])

#make a DataFrame
df_facts = pd.DataFrame({"Cat Fact": facts})

#print the results
print("\n🐱Cat Facts Table:\n")
print(df_facts)

#save to a CSV
df_facts.to_csv("cat_facts.csv", index=False)
print("\n💾 Saved 'cat_facts.csv' successfully!")
# Out:
# 🐱Cat Facts Table:
#
#                                             Cat Fact
# 0  According to a Gallup poll, most American pet ...
# 1  A cat usually has about 12 whiskers on each si...
# 2  The way you treat kittens in the early stages ...
# 3  During the Middle Ages, cats were associated w...
# 4  Perhaps the most famous comic cat is the Chesh...
#
# 💾 Saved 'cat_facts.csv' successfully!
